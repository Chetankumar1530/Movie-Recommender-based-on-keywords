# %%
import pandas as pd

# %%
data = pd.read_csv("Data With NLP.csv")

# %%
data["url"] = 0
data
# Out:
#            Movie Title    IMDB ID              title  Ratinng Release Date  \
# 0             3 Idiots  tt1187043           3 Idiots      8.4         2009
# 1     Taare Zameen Par  tt0986264   Taare Zameen Par      8.3         2007
# 2                   PK  tt2338151                 PK      8.1         2014
# 3               Dangal  tt5074352             Dangal      8.3         2016
# 4      Rang De Basanti  tt0405508    Rang De Basanti      8.1         2006
# ..                 ...        ...                ...      ...          ...
# 806   Parde Ke Peechey  tt0314487   Parde Ke Peechey      5.9         1971
# 807            Dhamkee  tt1263658           Baladoor      4.0         2008
# 808       Chhoo Mantar  tt0049071       Chhoo Mantar      6.0         1956
# 809  Ladki Sahyadri Ki  tt0418818  Ladki Sahyadri Ki      5.0         1966
# 810          Madadgaar  tt0302682     Kankan De Ohle      7.2         1970
#
#                                 Genre  \
# ...

# %%
for i in range(0,len(data)):
    data["url"][i] = "https://www.imdb.com/title/"+data["IMDB ID"][i]+"/"
# Out:
# C:\Users\Chetan\AppData\Local\Temp\ipykernel_10548\3654947178.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["url"][i] = "https://www.imdb.com/title/"+data["IMDB ID"][i]+"/"

# %%
data.to_csv("Final Submission data part 9.csv")

# %%
data.to_excel("Final Submission.xlsx")
